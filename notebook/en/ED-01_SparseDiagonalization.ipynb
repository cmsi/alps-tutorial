# %% [markdown]
# # ALPS_2_Tutorials:ED-01_SparseDiagonalization

# %% [markdown]
# #  Sparse diagonalization

# %% [markdown]
# In this tutorial we will lear how to use the sparse diagonalization program using the Lanczos algorithm.

# %% [markdown]
# ## Measurements on a 1-dimensional Heisenberg chain

# %% [markdown]
# To set up and run the simulation in Python we use the script  [tutorial1a.py](http://alps.comp-phys.org/static/tutorials2.2.0/ed-01-sparsediag/tutorial1a.py). The first parts of this script imports the required modules, prepares the input files as a list of Python dictionaries, writes the input files and runs the application

# %%
import pyalps
parms = [{ 
         'LATTICE'                   : "chain lattice", 
         'MODEL'                     : "spin",
         'local_S'                   : 1,
         'J'                         : 1,
         'L'                         : 4,
         'CONSERVED_QUANTUMNUMBERS'  : 'Sz',
         'MEASURE_STRUCTURE_FACTOR[Structure Factor S]'        : 'Sz',
         'MEASURE_CORRELATIONS[Diagonal spin correlations]='   : 'Sz',
         'MEASURE_CORRELATIONS[Offdiagonal spin correlations]' : 'Splus:Sminus'
       }]

# %%
input_file = pyalps.writeInputFiles('parm1a',parms)
res = pyalps.runApplication('sparsediag',input_file)

# %% [markdown]
# To run this, launch your python interpreter using the convenience scripts <tt>alpspython</tt> or <tt>vispython</tt>. We now have the same output files as in the command line version.

# %% [markdown]
# We next load the measurements for each of the calculated eigenstates:

# %%
data = pyalps.loadEigenstateMeasurements(pyalps.getResultFiles(prefix='parm1a'))

# %% [markdown]
# and then print the results just for the ground state:

# %%
for sector in data[0]:
    print '\nSector with Sz =', sector[0].props['Sz'], 
    print 'and k =', sector[0].props['TOTAL_MOMENTUM']
    for s in sector:
        if pyalps.size(s.y[0])==1:
            print s.props['observable'], ' : ', s.y[0]
        else:
            for (x,y) in zip(s.x,s.y[0]):
                print  s.props['observable'], '(', x, ') : ', y
# Out:
# Sector with Sz = -4.0 and k = 0.0
# Energy  :  4.0
# Offdiagonal spin correlations ( 0 ) :  0.0
# Offdiagonal spin correlations ( 1 ) :  0.0
# Offdiagonal spin correlations ( 2 ) :  0.0
# Offdiagonal spin correlations ( 3 ) :  0.0
# Structure Factor S ( 0.0 ) :  4.0
# Structure Factor S ( 1.5708 ) :  2.77555756156e-17
# Structure Factor S ( 3.14159 ) :  0.0
# Structure Factor S ( -1.5708 ) :  2.77555756156e-17
#
# Sector with Sz = 1.0 and k = 1.57079632679
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.53333333333
# Offdiagonal spin correlations ( 1 ) :  -0.45
# Offdiagonal spin correlations ( 2 ) :  -0.133333333333
# Offdiagonal spin correlations ( 3 ) :  -0.45
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.583333333333
# Structure Factor S ( 3.14159 ) :  1.45
# Structure Factor S ( -1.5708 ) :  0.583333333333
#
# Sector with Sz = -2.0 and k = 0.0
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  0.904761904762
# Offdiagonal spin correlations ( 1 ) :  -0.857142857143
# Offdiagonal spin correlations ( 2 ) :  0.809523809524
# Offdiagonal spin correlations ( 3 ) :  -0.857142857143
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.404761904762
# Structure Factor S ( 3.14159 ) :  0.571428571429
# Structure Factor S ( -1.5708 ) :  0.404761904762
#
# Sector with Sz = -1.0 and k = 3.14159265359
# Energy  :  -5.0
# Offdiagonal spin correlations ( 0 ) :  1.2
# Offdiagonal spin correlations ( 1 ) :  -1.05
# Offdiagonal spin correlations ( 2 ) :  0.9
# Offdiagonal spin correlations ( 3 ) :  -1.05
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.45
# Structure Factor S ( 3.14159 ) :  1.05
# Structure Factor S ( -1.5708 ) :  0.45
#
# Sector with Sz = -3.0 and k = 4.71238898038
# Energy  :  2.0
# Offdiagonal spin correlations ( 0 ) :  0.5
# Offdiagonal spin correlations ( 1 ) :  -9.18485099361e-17
# Offdiagonal spin correlations ( 2 ) :  -0.5
# Offdiagonal spin correlations ( 3 ) :  2.75545529808e-16
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = -1.0 and k = 4.71238898038
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.03333333333
# Offdiagonal spin correlations ( 1 ) :  -0.45
# Offdiagonal spin correlations ( 2 ) :  -0.133333333333
# Offdiagonal spin correlations ( 3 ) :  -0.45
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.583333333333
# Structure Factor S ( 3.14159 ) :  1.45
# Structure Factor S ( -1.5708 ) :  0.583333333333
#
# Sector with Sz = 4.0 and k = 0.0
# Energy  :  4.0
# Offdiagonal spin correlations ( 0 ) :  2.0
# Offdiagonal spin correlations ( 1 ) :  0.0
# Offdiagonal spin correlations ( 2 ) :  0.0
# Offdiagonal spin correlations ( 3 ) :  0.0
# Structure Factor S ( 0.0 ) :  4.0
# Structure Factor S ( 1.5708 ) :  2.77555756156e-17
# Structure Factor S ( 3.14159 ) :  0.0
# Structure Factor S ( -1.5708 ) :  2.77555756156e-17
#
# Sector with Sz = -2.0 and k = 4.71238898038
# Energy  :  -1.0
# Offdiagonal spin correlations ( 0 ) :  0.666666666667
# Offdiagonal spin correlations ( 1 ) :  -0.333333333333
# Offdiagonal spin correlations ( 2 ) :  8.32667268469e-17
# Offdiagonal spin correlations ( 3 ) :  -0.333333333333
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.833333333333
# Structure Factor S ( 3.14159 ) :  0.666666666667
# Structure Factor S ( -1.5708 ) :  0.833333333333
#
# Sector with Sz = 2.0 and k = 3.14159265359
# Energy  :  2.77555756156e-17
# Offdiagonal spin correlations ( 0 ) :  1.93030611715
# Offdiagonal spin correlations ( 1 ) :  3.38963670212e-32
# Offdiagonal spin correlations ( 2 ) :  0.489813875806
# Offdiagonal spin correlations ( 3 ) :  -4.62223186653e-32
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.13938776569
# Structure Factor S ( 3.14159 ) :  1.0
# Structure Factor S ( -1.5708 ) :  0.13938776569
#
# Sector with Sz = -1.0 and k = 0.0
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.04761904762
# Offdiagonal spin correlations ( 1 ) :  -0.321428571429
# Offdiagonal spin correlations ( 2 ) :  0.595238095238
# Offdiagonal spin correlations ( 3 ) :  -0.321428571429
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.297619047619
# Structure Factor S ( 3.14159 ) :  1.96428571429
# Structure Factor S ( -1.5708 ) :  0.297619047619
#
# Sector with Sz = 3.0 and k = 3.14159265359
# Energy  :  -4.4408920985e-16
# Offdiagonal spin correlations ( 0 ) :  2.0
# Offdiagonal spin correlations ( 1 ) :  -0.5
# Offdiagonal spin correlations ( 2 ) :  0.5
# Offdiagonal spin correlations ( 3 ) :  -0.5
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = 1.0 and k = 3.14159265359
# Energy  :  -5.0
# Offdiagonal spin correlations ( 0 ) :  1.7
# Offdiagonal spin correlations ( 1 ) :  -1.05
# Offdiagonal spin correlations ( 2 ) :  0.9
# Offdiagonal spin correlations ( 3 ) :  -1.05
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.45
# Structure Factor S ( 3.14159 ) :  1.05
# Structure Factor S ( -1.5708 ) :  0.45
#
# Sector with Sz = 3.0 and k = 0.0
# Energy  :  4.0
# Offdiagonal spin correlations ( 0 ) :  2.0
# Offdiagonal spin correlations ( 1 ) :  0.5
# Offdiagonal spin correlations ( 2 ) :  0.5
# Offdiagonal spin correlations ( 3 ) :  0.5
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = 2.0 and k = 1.57079632679
# Energy  :  -1.0
# Offdiagonal spin correlations ( 0 ) :  1.66666666667
# Offdiagonal spin correlations ( 1 ) :  -0.333333333333
# Offdiagonal spin correlations ( 2 ) :  -1.38777878078e-17
# Offdiagonal spin correlations ( 3 ) :  -0.333333333333
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.833333333333
# Structure Factor S ( 3.14159 ) :  0.666666666667
# Structure Factor S ( -1.5708 ) :  0.833333333333
#
# Sector with Sz = 0.0 and k = 0.0
# Energy  :  -6.0
# Offdiagonal spin correlations ( 0 ) :  1.33333333333
# Offdiagonal spin correlations ( 1 ) :  -1.0
# Offdiagonal spin correlations ( 2 ) :  0.666666666667
# Offdiagonal spin correlations ( 3 ) :  -1.0
# Structure Factor S ( 0.0 ) :  -2.77555756156e-17
# Structure Factor S ( 1.5708 ) :  0.333333333333
# Structure Factor S ( 3.14159 ) :  2.0
# Structure Factor S ( -1.5708 ) :  0.333333333333
#
# Sector with Sz = 1.0 and k = 4.71238898038
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.53333333333
# Offdiagonal spin correlations ( 1 ) :  -0.45
# Offdiagonal spin correlations ( 2 ) :  -0.133333333333
# Offdiagonal spin correlations ( 3 ) :  -0.45
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.583333333333
# Structure Factor S ( 3.14159 ) :  1.45
# Structure Factor S ( -1.5708 ) :  0.583333333333
#
# Sector with Sz = 0.0 and k = 1.57079632679
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.43333333333
# Offdiagonal spin correlations ( 1 ) :  -0.6
# Offdiagonal spin correlations ( 2 ) :  0.266666666667
# Offdiagonal spin correlations ( 3 ) :  -0.6
# Structure Factor S ( 0.0 ) :  -2.77555756156e-17
# Structure Factor S ( 1.5708 ) :  0.833333333333
# Structure Factor S ( 3.14159 ) :  0.6
# Structure Factor S ( -1.5708 ) :  0.833333333333
#
# Sector with Sz = -3.0 and k = 0.0
# Energy  :  4.0
# Offdiagonal spin correlations ( 0 ) :  0.5
# Offdiagonal spin correlations ( 1 ) :  0.5
# Offdiagonal spin correlations ( 2 ) :  0.5
# Offdiagonal spin correlations ( 3 ) :  0.5
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = 0.0 and k = 4.71238898038
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.43333333333
# Offdiagonal spin correlations ( 1 ) :  -0.6
# Offdiagonal spin correlations ( 2 ) :  0.266666666667
# Offdiagonal spin correlations ( 3 ) :  -0.6
# Structure Factor S ( 0.0 ) :  2.77555756156e-17
# Structure Factor S ( 1.5708 ) :  0.833333333333
# Structure Factor S ( 3.14159 ) :  0.6
# Structure Factor S ( -1.5708 ) :  0.833333333333
#
# Sector with Sz = 1.0 and k = 0.0
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.54761904762
# Offdiagonal spin correlations ( 1 ) :  -0.321428571429
# Offdiagonal spin correlations ( 2 ) :  0.595238095238
# Offdiagonal spin correlations ( 3 ) :  -0.321428571429
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.297619047619
# Structure Factor S ( 3.14159 ) :  1.96428571429
# Structure Factor S ( -1.5708 ) :  0.297619047619
#
# Sector with Sz = -3.0 and k = 1.57079632679
# Energy  :  2.0
# Offdiagonal spin correlations ( 0 ) :  0.5
# Offdiagonal spin correlations ( 1 ) :  3.06161699787e-17
# Offdiagonal spin correlations ( 2 ) :  -0.5
# Offdiagonal spin correlations ( 3 ) :  -9.18485099361e-17
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = 3.0 and k = 1.57079632679
# Energy  :  2.0
# Offdiagonal spin correlations ( 0 ) :  2.0
# Offdiagonal spin correlations ( 1 ) :  -9.18485099361e-17
# Offdiagonal spin correlations ( 2 ) :  -0.5
# Offdiagonal spin correlations ( 3 ) :  3.06161699787e-17
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = -3.0 and k = 3.14159265359
# Energy  :  -4.4408920985e-16
# Offdiagonal spin correlations ( 0 ) :  0.5
# Offdiagonal spin correlations ( 1 ) :  -0.5
# Offdiagonal spin correlations ( 2 ) :  0.5
# Offdiagonal spin correlations ( 3 ) :  -0.5
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = 2.0 and k = 4.71238898038
# Energy  :  -1.0
# Offdiagonal spin correlations ( 0 ) :  1.66666666667
# Offdiagonal spin correlations ( 1 ) :  -0.333333333333
# Offdiagonal spin correlations ( 2 ) :  5.55111512313e-17
# Offdiagonal spin correlations ( 3 ) :  -0.333333333333
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.833333333333
# Structure Factor S ( 3.14159 ) :  0.666666666667
# Structure Factor S ( -1.5708 ) :  0.833333333333
#
# Sector with Sz = -1.0 and k = 1.57079632679
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.03333333333
# Offdiagonal spin correlations ( 1 ) :  -0.45
# Offdiagonal spin correlations ( 2 ) :  -0.133333333333
# Offdiagonal spin correlations ( 3 ) :  -0.45
# Structure Factor S ( 0.0 ) :  0.25
# Structure Factor S ( 1.5708 ) :  0.583333333333
# Structure Factor S ( 3.14159 ) :  1.45
# Structure Factor S ( -1.5708 ) :  0.583333333333
#
# Sector with Sz = 3.0 and k = 4.71238898038
# Energy  :  2.0
# Offdiagonal spin correlations ( 0 ) :  2.0
# Offdiagonal spin correlations ( 1 ) :  2.75545529808e-16
# Offdiagonal spin correlations ( 2 ) :  -0.5
# Offdiagonal spin correlations ( 3 ) :  -9.18485099361e-17
# Structure Factor S ( 0.0 ) :  2.25
# Structure Factor S ( 1.5708 ) :  0.25
# Structure Factor S ( 3.14159 ) :  0.25
# Structure Factor S ( -1.5708 ) :  0.25
#
# Sector with Sz = -2.0 and k = 1.57079632679
# Energy  :  -1.0
# Offdiagonal spin correlations ( 0 ) :  0.666666666667
# Offdiagonal spin correlations ( 1 ) :  -0.333333333333
# Offdiagonal spin correlations ( 2 ) :  -2.77555756156e-17
# Offdiagonal spin correlations ( 3 ) :  -0.333333333333
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.833333333333
# Structure Factor S ( 3.14159 ) :  0.666666666667
# Structure Factor S ( -1.5708 ) :  0.833333333333
#
# Sector with Sz = 0.0 and k = 3.14159265359
# Energy  :  -5.0
# Offdiagonal spin correlations ( 0 ) :  1.1
# Offdiagonal spin correlations ( 1 ) :  -0.4
# Offdiagonal spin correlations ( 2 ) :  0.2
# Offdiagonal spin correlations ( 3 ) :  -0.4
# Structure Factor S ( 0.0 ) :  2.77555756156e-17
# Structure Factor S ( 1.5708 ) :  0.1
# Structure Factor S ( 3.14159 ) :  3.4
# Structure Factor S ( -1.5708 ) :  0.1
#
# Sector with Sz = 2.0 and k = 0.0
# Energy  :  -3.0
# Offdiagonal spin correlations ( 0 ) :  1.90476190476
# Offdiagonal spin correlations ( 1 ) :  -0.857142857143
# Offdiagonal spin correlations ( 2 ) :  0.809523809524
# Offdiagonal spin correlations ( 3 ) :  -0.857142857143
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.404761904762
# Structure Factor S ( 3.14159 ) :  0.571428571429
# Structure Factor S ( -1.5708 ) :  0.404761904762
#
# Sector with Sz = -2.0 and k = 3.14159265359
# Energy  :  2.77555756156e-17
# Offdiagonal spin correlations ( 0 ) :  0.930306117155
# Offdiagonal spin correlations ( 1 ) :  3.38963670212e-32
# Offdiagonal spin correlations ( 2 ) :  0.489813875806
# Offdiagonal spin correlations ( 3 ) :  -3.08148791102e-32
# Structure Factor S ( 0.0 ) :  1.0
# Structure Factor S ( 1.5708 ) :  0.13938776569
# Structure Factor S ( 3.14159 ) :  1.0
# Structure Factor S ( -1.5708 ) :  0.13938776569
